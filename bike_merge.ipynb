# %%
import pandas as pd
import csv

# %%
citibikejc_201801 = pd.read_csv("data/201801_citibikejc_tripdata.csv")
citibikejc_201802 = pd.read_csv("data/201802_citibikejc_tripdata.csv")
citibikejc_201803 = pd.read_csv("data/201803_citibikejc_tripdata.csv")
citibikejc_201701 = pd.read_csv("data/JC-201701-citibike-tripdata.csv")
citibikejc_201702 = pd.read_csv("data/JC-201702-citibike-tripdata.csv")
citibikejc_201703 = pd.read_csv("data/JC-201703-citibike-tripdata.csv")
citibikejc_201704 = pd.read_csv("data/JC-201704-citibike-tripdata.csv")
citibikejc_201705 = pd.read_csv("data/JC-201705-citibike-tripdata.csv")
citibikejc_201706 = pd.read_csv("data/JC-201706-citibike-tripdata.csv")
citibikejc_201707 = pd.read_csv("data/JC-201707-citibike-tripdata.csv")
citibikejc_201708 = pd.read_csv("data/JC-201708-citibike-tripdata.csv")
citibikejc_201709 = pd.read_csv("data/JC-201709-citibike-tripdata.csv")
citibikejc_201710 = pd.read_csv("data/JC-201710-citibike-tripdata.csv")
citibikejc_201711 = pd.read_csv("data/JC-201711-citibike-tripdata.csv")
citibikejc_201712 = pd.read_csv("data/JC-201712-citibike-tripdata.csv")

# %%
final_df = pd.concat([citibikejc_201801, citibikejc_201802, citibikejc_201803, citibikejc_201704, citibikejc_201705, citibikejc_201706, citibikejc_201707, citibikejc_201708, citibikejc_201709, citibikejc_201710, citibikejc_201711, citibikejc_201712])

# %%
final_df
# Out:
#        bikeid  birth year  end station id  end station latitude  \
# 0       29590      1964.0            3211             40.721525
# 1       29613      1989.0            3269             40.726012
# 2       31940      1994.0            3225             40.723659
# 3       31949      1964.0            3278             40.725685
# 4       31929      1992.0            3199             40.728745
# 5       31920      1976.0            3213             40.718489
# 6       31678      1994.0            3280             40.719282
# 7       29634      1990.0            3198             40.748716
# 8       29626      1988.0            3267             40.712419
# 9       31760      1988.0            3213             40.718489
# 10      29622      1989.0            3276             40.714584
# 11      31907      1981.0            3199             40.728745
# 12      32795      1970.0            3201             40.737711
# 13      31743      1993.0            3267             40.712419
# ...

# %%
final_df.to_csv("result.csv")
